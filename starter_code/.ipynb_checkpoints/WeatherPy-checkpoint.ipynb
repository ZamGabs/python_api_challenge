# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 619

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url="http://api.openweathermap.org/data/2.5/weather?"#q={city name}&appid={API key}
units="imperial"
wkey = "bd6639a159b665b11fe80eaad7b218c5"
appid = wkey
settings = {"units": "imperial", "appid": wkey}
url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=bd6639a159b665b11fe80eaad7b218c5&units=imperial&q='

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + appid
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

for city in cities:
    city_url = url + "&q=" + city
    print(city_url)
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_mtemp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_cloudiness = city_weather['clouds']['all']
        city_wspeed = city_weather['wind']['speed']
        city_data.append({"city":city,
                      "Latitude":city_lat,
                      "Max Temp":city_mtemp,
                      "Humidity":city_humidity,
                      "Cloudiness":city_cloudiness,
                      "Wind Speed":city_wspeed,
                      })
    except:
        print("city not found")
        pass

# Indicate that Data Loading is complete 
print("Data Retrieval Complete  ")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=da nang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dukhovshchina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pakdasht
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hohhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=clarence town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=muhos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=samusu
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=huarmey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dospat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rancharia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=camargo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=la ligua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=wajid
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kananga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=illoqqortoormiut
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=toora-khem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kolyubakino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vernon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=neryungri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=havelock
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=marrakesh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=gejiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=abha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sloboda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pimenta bueno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=burica
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=praya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pyapon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=alice springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=altay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=taolanaro
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=penzance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bababe
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kuche
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nizhneyansk
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=monterey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yatou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=quatre cocos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=middelburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=antofagasta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=varhaug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=albenga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=wasilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kodinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=henzada
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nioro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kangaatsiaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=richmond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint-joseph
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=salamiyah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=soubre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=orta nova
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=guantanamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bolungarvik
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bridlington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kampong thum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kropotkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kyrylivka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=martapura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=booue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=barretos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=amderma
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chifeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=awbari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saraland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=darhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nabire
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sawakin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=belushya guba
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=biharamulo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hauterive
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saleaula
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=villazon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=manali
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=attawapiskat
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=marcona
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=khormuj
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=waitati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=simao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=gualeguay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=somerset east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=port keats
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mezen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ketchikan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tarko-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yurimaguas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tabuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kantunilkin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mendahara
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=edson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=morant bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ayios vasilios
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=agdas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=zheleznodorozhnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ierapetra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bargal
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=paradwip
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ajdabiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=port-cartier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hodmezovasarhely
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sodhra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mason city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bucerias
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pangai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=santa rosalia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kamenskoye
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hanzhong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rudbar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=central point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=the pas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chipinge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sao francisco de assis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kitui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=novosheshminsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yokadouma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kochinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=grand river south east
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=zolotinka
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bairiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=barentsburg
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=funtua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bar harbor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vedaranniyam
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rio cuarto
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pedernales
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pocone
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=le port
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pravia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mys shmidta
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dzhebariki-khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=stephenville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bahia blanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=luqiao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=livingston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ropczyce
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ndjole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=inuvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=asbe teferi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=temaraia
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sorvag
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dudinka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tsihombe
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=deming
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=krasnovishersk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saryshagan
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bolgar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=asansol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=carballo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=palestine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=maragogi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=atasu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sulangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=uglovskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=porosozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=aripuana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=puri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ayame
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=havre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lakes entrance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=namtsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=xai-xai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lebedinyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bruiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint helens
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=staraya mayna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=callaway
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ilovlya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=suez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=aybak
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rio claro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=buluang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chihuahua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ukiah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=miragoane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint-francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tumannyy
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mecca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=phan rang
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=uzumlu
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mrirt
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sentyabrskiy
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=richards bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=razdolinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lushunkou
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=wilmington island
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=angren
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ankpa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=todos santos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yelovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=avera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=forbes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=candolim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=iskateley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=caucaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=senneterre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=alappuzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sarh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sao mateus do maranhao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=san lawrenz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ileza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=svetlaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=eyrarbakki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=boca do acre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=qafsah
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=minna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=severnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=otane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mlimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rognan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hayden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=giyani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=raton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kazbegi
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=iquique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=puerto colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=novobirilyussy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mozarlandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cap-haitien
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pinawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hamina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=barbar
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mayumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ode
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=atikokan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chortomlyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=walvis bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=panikian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=arcachon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vila velha
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vetluga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=puma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lolua
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hailar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mukhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tual
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lillooet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=jinxiang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tolaga bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chiredzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lloydminster
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=luyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vrede
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=guiratinga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=troitsko-pechorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=morondava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=fukue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ranong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=chakwal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=jabiru
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lugovskiy
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=toliary
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=matagami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sompeta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=valdivia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kutum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=karasburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=karoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=luanda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mugango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=abalak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=darnah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yabelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yenagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=harper
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yomitan
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=orlik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ialibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=flinders
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=thaba-tseka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sandpoint
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mehamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tofield
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nguiu
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=fort-shevchenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=playa vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yaqui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mitchell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=umzimvubu
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=wanning
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=aguimes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hunza
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pasinler
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=oliveira dos brejinhos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=glendive
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ayaviri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=poputnaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=asfi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=paamiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saurimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=arroio dos ratos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint augustine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ponta pora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=exarkhos
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=swellendam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tumut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vestmanna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mocambique
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=wulanhaote
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=acapulco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=grand centre
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=shache
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vanino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=strelka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=yantal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=cesis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=caborca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=sena madureira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kidal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ormara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=khulo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lock haven
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mahon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=bima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=goya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=kuusamo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tarata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=nelson bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=masvingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=banmo
# city not found
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=upington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=saint-denis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=caconda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=korla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=mosjoen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tezu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=tigil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=pampierstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bd6639a159b665b11fe80eaad7b218c5&q=vidim
# Data Retrieval Complete

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Export the City_Data into a csv
city_data_pd.to_csv("WeatherPy.csv",encoding="utf-8",index=False)


#Count
city_data_pd.count()
# Out:
# city          562
# Latitude      562
# Max Temp      562
# Humidity      562
# Cloudiness    562
# Wind Speed    562
# dtype: int64

# %%
#Display City Data Frame 
city_data_pd.head()
# Out:
#             city  Latitude  Max Temp  Humidity  Cloudiness  Wind Speed
# 0         namibe    -15.20     69.35        79          69        3.29
# 1         bethel     41.37     53.60        93          90        4.70
# 2        da nang     16.07     77.00        88          75        5.82
# 3  mar del plata    -38.00     57.20        67           0        5.82
# 4  pacific grove     36.62     73.00        16           1        5.82

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Scatter Plot for Latitude vs Temperature
plt.scatter(city_data_pd["Latitude"], 
            city_data_pd["Max Temp"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Graph Properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

#Saving Diagream
plt.savefig("Latitude vs Temperature (F).png")

#Display plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#Scatter Plots for each City
plt.scatter(city_data_pd["Latitude"], 
            city_data_pd["Humidity"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Graph Properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving figure
plt.savefig("Latitude vs Humidity (%).png")

#Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#Scatter Plot
plt.scatter(city_data_pd["Latitude"], 
            city_data_pd["Cloudiness"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Graph Properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

#Saving Figure
plt.savefig("Latitude vs Cloudiness (%).png")

#Display Plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
#Scatter Plot
plt.scatter(city_data_pd["Latitude"], 
            city_data_pd["Wind Speed"],
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

#Graph Properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

#Saving
plt.savefig("Latitude vs Wind Speed (MPH).png")

#Plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.8151657406810827

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.760263355051646

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.10358336015746494

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.14689473425583055

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.21881426893991618

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: 0.1071382774388479

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-squared is: -0.322483077139538
